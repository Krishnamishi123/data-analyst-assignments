# %%
"""
Q1. Handle Missing Values (Basic Cleaning)

Fill missing values using the following:

Age → Median

Salary → Mean

Hours_Worked_Per_Week → Median

Performance_Score → Mean

Display the dataset after handling missing values.
"""
import pandas as pd
df=pd.read_csv(r"C:\Users\91630\Downloads\employee_productivity_dataset.csv")
df['Age'].fillna(df['Age'].median(), inplace=True)
df['Salary'].fillna(df['Salary'].mean(), inplace=True)
df['Hours_Worked_Per_Week'].fillna(df['Hours_Worked_Per_Week'].median(), inplace=True)
df['Performance_Score'].fillna(df['Performance_Score'].mean(), inplace=True)
print(df)
# Out:
#     Employee_ID         Name Department   Age  Gender Work_Mode   Join_Date  \
# 0          E001  Amit Sharma         IT  25.0    Male    Remote  15-01-2021
# 1          E002   Riya Patel         HR  30.0  Female    Hybrid  15-02-2020
# 2          E003  John Mathew    Finance  29.0    Male    Onsite  10-03-2022
# 3          E004  Sneha Joshi         IT  28.0  Female    Remote  22-04-2021
# 4          E005  Arjun Verma  Marketing  35.0    Male    Hybrid  18-05-2020
# ..          ...          ...        ...   ...     ...       ...         ...
# 245        E006   Neha Singh         HR  27.0  Female    Remote  01-06-2023
# 246        E007    Rahul Das    Finance  40.0    Male    Onsite  07-07-2019
# 247        E008  Pooja Mehta  Marketing  29.0  Female    Hybrid  12-08-2022
# 248        E009  Sameer Khan         IT  31.0    Male    Remote  30-09-2021
# 249        E010   Kiran Nair         HR  26.0  Female    Onsite  05-10-2023
#
# ...

# %%
"""
Q2. Label Encoding

Convert these columns into numeric values using Label Encoding:

Gender

Department

Show the updated columns.
"""
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Gender']=le.fit_transform(df['Gender'])
df['Department']=le.fit_transform(df['Department'])
print(df)
# Out:
#     Employee_ID         Name  Department   Age  Gender Work_Mode   Join_Date  \
# 0          E001  Amit Sharma           2  25.0       1    Remote  15-01-2021
# 1          E002   Riya Patel           1  30.0       0    Hybrid  15-02-2020
# 2          E003  John Mathew           0  29.0       1    Onsite  10-03-2022
# 3          E004  Sneha Joshi           2  28.0       0    Remote  22-04-2021
# 4          E005  Arjun Verma           3  35.0       1    Hybrid  18-05-2020
# ..          ...          ...         ...   ...     ...       ...         ...
# 245        E006   Neha Singh           1  27.0       0    Remote  01-06-2023
# 246        E007    Rahul Das           0  40.0       1    Onsite  07-07-2019
# 247        E008  Pooja Mehta           3  29.0       0    Hybrid  12-08-2022
# 248        E009  Sameer Khan           2  31.0       1    Remote  30-09-2021
# 249        E010   Kiran Nair           1  26.0       0    Onsite  05-10-2023
#
# ...

# %%
"""
Q3. One-Hot Encoding

Apply One-Hot Encoding on:

Work_Mode

Location

Display the dataset and check how many new columns are created.
"""
original_len = len(df.columns)
df = pd.get_dummies(df, columns=['Work_Mode', 'Location'])
print(df)
print("Number of new columns created:", len(df.columns) - original_len)
# here we already have one hot encoding in the dataset so we are getting 0 new columns created.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [10], in <cell line: 13>()
#       1 """
#       2 Q3. One-Hot Encoding
#       3
#    (...)
#      10 Display the dataset and check how many new columns are created.
#      11 """
#      12 original_len = len(df.columns)
# ---> 13 df = pd.get_dummies(df, columns=['Work_Mode', 'Location'])
#      14 print(df)
#      15 print("Number of new columns created:", len(df.columns) - original_len)
#
# File c:\Users\91630\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\encoding.py:170, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     168     raise TypeError("Input must be a list-like for parameter `columns`")
#     169 else:
# --> 170     data_to_encode = data[columns]
#     172 # validate prefixes and separator to avoid silently dropping cols
# ...

# %%
"""
Q4. Normalization (Min-Max Scaling)

Normalize the following columns:

Salary

Hours_Worked_Per_Week

Use MinMaxScaler and display results.
"""
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
df[['Salary']] = scaler.fit_transform(df[['Salary']])
df[['Hours_Worked_Per_Week']] = scaler.fit_transform(df[['Hours_Worked_Per_Week']])
print(df)
# Out:
#     Employee_ID         Name  Department   Age  Gender   Join_Date  \
# 0          E001  Amit Sharma           2  25.0       1  15-01-2021
# 1          E002   Riya Patel           1  30.0       0  15-02-2020
# 2          E003  John Mathew           0  29.0       1  10-03-2022
# 3          E004  Sneha Joshi           2  28.0       0  22-04-2021
# 4          E005  Arjun Verma           3  35.0       1  18-05-2020
# ..          ...          ...         ...   ...     ...         ...
# 245        E006   Neha Singh           1  27.0       0  01-06-2023
# 246        E007    Rahul Das           0  40.0       1  07-07-2019
# 247        E008  Pooja Mehta           3  29.0       0  12-08-2022
# 248        E009  Sameer Khan           2  31.0       1  30-09-2021
# 249        E010   Kiran Nair           1  26.0       0  05-10-2023
#
#      Hours_Worked_Per_Week  Projects_Completed  Performance_Score    Salary  \
# 0                 0.285714                   5             4.5000  0.347826
# ...

# %%
"""
Q5. Standardization (Scaling)

Apply StandardScaler on:

Age
Projects_Completed

Display the transformed values.
"""
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
df[['Age']]=scaler.fit_transform(df[['Age']])
df[['Projects_Completed']]=scaler.fit_transform(df[['Projects_Completed']])
print(df)
# Out:
#     Employee_ID         Name  Department           Age  Gender   Join_Date  \
# 0          E001  Amit Sharma           2 -1.172018e+00       1  15-01-2021
# 1          E002   Riya Patel           1 -1.598721e-17       0  15-02-2020
# 2          E003  John Mathew           0 -2.344036e-01       1  10-03-2022
# 3          E004  Sneha Joshi           2 -4.688072e-01       0  22-04-2021
# 4          E005  Arjun Verma           3  1.172018e+00       1  18-05-2020
# ..          ...          ...         ...           ...     ...         ...
# 245        E006   Neha Singh           1 -7.032108e-01       0  01-06-2023
# 246        E007    Rahul Das           0  2.344036e+00       1  07-07-2019
# 247        E008  Pooja Mehta           3 -2.344036e-01       0  12-08-2022
# 248        E009  Sameer Khan           2  2.344036e-01       1  30-09-2021
# 249        E010   Kiran Nair           1 -9.376145e-01       0  05-10-2023
#
# ...

# %%
"""
Q6. Compare Scaling Methods

Apply both:

MinMaxScaler

StandardScaler

On the Salary column.

Show both results side by side.
"""
from sklearn.preprocessing import MinMaxScaler, StandardScaler
min_max_scaler=MinMaxScaler()
standard_scaler=StandardScaler()
df['salary_min_max']=min_max_scaler.fit_transform(df[['Salary']])
df['salary_standard']=standard_scaler.fit_transform(df[['Salary']])
print(df['salary_min_max'])
print(df['salary_standard'])
# Out:
# 0      0.347826
# 1      0.130435
# 2      0.782609
# 3      0.434783
# 4      0.376812
#          ...
# 245    0.000000
# 246    1.000000
# 247    0.260870
# 248    0.391304
# 249    0.043478
# Name: salary_min_max, Length: 250, dtype: float64
# 0     -9.745089e-02
# 1     -8.283326e-01
# 2      1.364312e+00
# 3      1.949018e-01
# 4     -3.732632e-16
#            ...
# 245   -1.266862e+00
# 246    2.095194e+00
# 247   -3.898036e-01
# 248    4.872545e-02
# 249   -1.120685e+00
# Name: salary_standard, Length: 250, dtype: float64

# %%
"""
Q7. Build Preprocessing Pipeline
Create a pipeline that:
Applies encoding to categorical columns
Applies scaling to numerical columns
Use:
ColumnTransformer
Pipeline

"""
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
categorical_features=['Gender','Department']
numerical_features=['Age','Salary','Hours_Worked_Per_Week','Performance_Score','Projects_Completed']
categorical_features_transformer=OneHotEncoder()
numerical_features_transformer=StandardScaler()
column_transformer=ColumnTransformer(
    transformers=[
        ('cat', categorical_features_transformer, categorical_features),
        ('num', numerical_features_transformer, numerical_features)
    ]
)
total_transformed_data=column_transformer.fit_transform(df)
print(total_transformed_data)
# Out:
# [[ 0.          1.          0.         ... -0.4112205   0.68522446
#   -0.21160368]
#  [ 1.          0.          0.         ... -0.86813216 -1.14204076
#   -0.9169493 ]
#  [ 0.          1.          1.         ...  0.73105866  0.
#    0.49374193]
#  ...
#  [ 1.          0.          0.         ...  0.04569117 -0.04568163
#    0.49374193]
#  [ 0.          1.          0.         ... -0.18276466 -0.77658772
#   -0.21160368]
#  [ 1.          0.          0.         ... -1.09658799  0.
#   -0.9169493 ]]

# %%
"""
Q8. Apply Pipeline

Apply the pipeline on the dataset.

Display:

Transformed dataset

Shape of final dataset
"""
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
categorical_features=['Gender','Department']
numerical_features=['Age','Salary','Hours_Worked_Per_Week','Performance_Score','Projects_Completed']
categorical_features_transformer=OneHotEncoder()
numerical_features_transformer=StandardScaler()
column_transformer=ColumnTransformer(
    transformers=[
        ('cat', categorical_features_transformer, categorical_features),
        ('num', numerical_features_transformer, numerical_features)
    ]
)

total_transformed_data=column_transformer.fit_transform(df)
print(total_transformed_data)
print("Shape of final dataset:", total_transformed_data.shape)
# Out:
# [[ 0.          1.          0.         ... -0.4112205   0.68522446
#   -0.21160368]
#  [ 1.          0.          0.         ... -0.86813216 -1.14204076
#   -0.9169493 ]
#  [ 0.          1.          1.         ...  0.73105866  0.
#    0.49374193]
#  ...
#  [ 1.          0.          0.         ...  0.04569117 -0.04568163
#    0.49374193]
#  [ 0.          1.          0.         ... -0.18276466 -0.77658772
#   -0.21160368]
#  [ 1.          0.          0.         ... -1.09658799  0.
#   -0.9169493 ]]
# Shape of final dataset: (250, 11)

# %%
"""
Q9. Conceptual Question

Why is scaling important in Python?

A9:-Scaling is important in Python, especially in the context of machine learning and data preprocessing, for several reasons:
1. Feature Importance: Scaling ensures that all features contribute equally to the model's learning process. 
If features are on different scales, the model may give more weight to those with larger ranges, leading to biased results.
2. Convergence: Many machine learning algorithms, such as gradient descent-based methods, converge faster when features are on a similar scale.
3. Distance-Based Algorithms: Algorithms like K-Nearest Neighbors and Support Vector Machines rely on distance calculations.
If features are on different scales, the distance calculations can be dominated by features with larger ranges, leading to poor performance.
4. Regularization: Scaling is crucial when using regularization techniques (like L1 or L2) to ensure that the penalty term is applied fairly across
 all features.
5. Interpretability: Scaled features can make it easier to interpret the importance of each feature in the model, as they are on a comparable scale.
Overall, scaling helps improve the performance and interpretability of machine learning models by ensuring that all features
are treated equally and that the model can learn effectively from the data.
"""
# Out:
# "\nQ9. Conceptual Question\n\nWhy is scaling important in Python?\n\nA9:-Scaling is important in Python, especially in the context of machine learning and data preprocessing, for several reasons:\n1. Feature Importance: Scaling ensures that all features contribute equally to the model's learning process. \nIf features are on different scales, the model may give more weight to those with larger ranges, leading to biased results.\n2. Convergence: Many machine learning algorithms, such as gradient descent-based methods, converge faster when features are on a similar scale.\n3. Distance-Based Algorithms: Algorithms like K-Nearest Neighbors and Support Vector Machines rely on distance calculations.\nIf features are on different scales, the distance calculations can be dominated by features with larger ranges, leading to poor performance.\n4. Regularization: Scaling is crucial when using regularization techniques (like L1 or L2) to ensure that the penalty term is applied fairly across\n al
# ...

# %%
"""
Q10. Conceptual Question

Why do we convert categorical data into numerical form?
A10:-We convert categorical data into numerical form because most machine learning algorithms and statistical models require numerical input to 
perform calculations and make predictions. Categorical data, which represents discrete values or categories, cannot be directly used in 
mathematical operations. By encoding categorical variables into numerical form (using techniques like Label Encoding or One-Hot Encoding), 
we can enable algorithms to process and learn from the data effectively. This conversion allows us to capture the relationships and patterns in the data, 
ultimately improving the performance of our models.
"""
